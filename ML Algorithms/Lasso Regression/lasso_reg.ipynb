# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
X,y= make_regression(n_samples=100, n_features=3, n_informative=3, n_targets=1, noise=15, random_state=42 )

# %% [markdown]
# # Train test split

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # Linear Regression

# %%
lr= LinearRegression()
lr.fit(X_train, y_train)
print("Coefficient: ", lr.coef_)
print("Intercept: ", lr.intercept_)
print("R2 Score for Normal Regression Line:", r2_score(y_test, lr.predict(X_test)))
# Out:
# Coefficient:  [-0.44274186 19.34501561 27.21056091]
# Intercept:  0.5494484587752602
# R2 Score for Normal Regression Line: 0.7642778584593021

# %% [markdown]
# # Applying Lasso Regression

# %%
alphas= [0.1, 1, 5, 10, 50]
for i in alphas:
    model= make_pipeline(StandardScaler(), Lasso(alpha=i))
    model.fit(X_train, y_train)
    print(f"R2 Score for alpha= {i}:", r2_score(y_test, model.predict(X_test)))
# Out:
# R2 Score for alpha= 0.1: 0.9598444075876645
# R2 Score for alpha= 1: 0.9613626133902567
# R2 Score for alpha= 5: 0.956884813312424
# R2 Score for alpha= 10: 0.9255149901319732
# R2 Score for alpha= 50: 0.4898356099463046
