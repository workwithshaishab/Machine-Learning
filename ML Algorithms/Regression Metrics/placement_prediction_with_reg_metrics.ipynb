# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
df= pd.read_csv("placement.csv")

# %%
df.sample(5)
# Out:
#      cgpa  package
# 109  7.77     4.06
# 143  4.85     1.54
# 60   5.61     2.19
# 98   7.69     3.83
# 20   7.28     3.16

# %%
X= df.iloc[:, 0:1]
y= df.iloc[:, -1]

# %%
X
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=0.2)

# %%
X_test
# Out:
#      cgpa
# 5    7.89
# 68   7.56
# 199  6.22
# 58   6.92
# 15   7.25
# 120  5.23
# 31   8.10
# 126  5.91
# 191  7.28
# 146  6.07
# 194  7.89
# 190  6.19
# 101  6.71
# 95   6.63
# 32   6.96
# 162  5.53
# 173  6.75
# 75   6.97
# 135  6.10
# 131  6.37
# 127  6.78
# 149  8.28
# 61   5.48
# 82   5.58
# 155  6.98
# 54   6.86
# 36   5.99
# 181  8.22
# 179  7.14
# 153  7.94
# 85   4.79
# 37   5.90
# 39   7.43
# 7    6.75
# 103  7.05
# 25   7.28
# 59   7.56
# 77   8.99
# 158  5.95
# 28   5.94

# %%
y_test
# Out:
# 5      2.99
# 68     2.99
# 199    2.33
# 58     3.09
# 15     3.23
# 120    1.73
# 31     3.89
# 126    2.60
# 191    3.48
# 146    2.46
# 194    3.67
# 190    2.69
# 101    3.52
# 95     2.79
# 32     3.08
# 162    2.55
# 173    2.56
# 75     3.28
# 135    2.60
# 131    2.01
# 127    3.11
# 149    3.67
# 61     1.61
# 82     2.17
# 155    3.09
# 54     3.09
# 36     2.84
# 181    3.89
# 179    3.03
# 153    3.99
# 85     1.48
# 37     2.43
# 39     3.33
# 7      2.48
# 103    3.00
# 25     3.65
# 59     3.31
# 77     4.60
# 158    3.04
# 28     2.24
# Name: package, dtype: float64

# %%
model= LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(X_test)
print(y_pred)
y_test.values
# Out:
# [3.48534895 3.30046961 2.54974742 2.94191573 3.12679507 1.99510938
#  3.60299945 2.37607288 3.14360228 2.46571135 3.48534895 2.5329402
#  2.82426523 2.779446   2.96432534 2.16318151 2.84667485 2.96992775
#  2.48251857 2.63378348 2.86348206 3.70384273 2.13516949 2.19119354
#  2.97553015 2.9083013  2.42089212 3.6702283  3.06516862 3.51336098
#  1.74860359 2.37047048 3.22763835 2.84667485 3.01474698 3.14360228
#  3.30046961 4.10161344 2.3984825  2.39288009]
# array([2.99, 2.99, 2.33, 3.09, 3.23, 1.73, 3.89, 2.6 , 3.48, 2.46, 3.67,
#        2.69, 3.52, 2.79, 3.08, 2.55, 2.56, 3.28, 2.6 , 2.01, 3.11, 3.67,
#        1.61, 2.17, 3.09, 3.09, 2.84, 3.89, 3.03, 3.99, 1.48, 2.43, 3.33,
#        2.48, 3.  , 3.65, 3.31, 4.6 , 3.04, 2.24])

# %% [markdown]
# # Regression metrics

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# MAE 0.25444286005934036

# %%
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# MSE 0.10057802757600871

# %%
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# RMSE 0.317140390956448

# %%
print("R2 Score:", r2_score(y_test, y_pred))
r2=  r2_score(y_test, y_pred)
# Out:
# R2 Score: 0.770129662963244

# %%
n= len(X_test)
k=1 
adjr2= 1- ((1-r2) * (n-1))/(n-1-k)
print("Adjusted R2 score:", adjr2)
# Out:
# Adjusted R2 score: 0.7640804435675399
